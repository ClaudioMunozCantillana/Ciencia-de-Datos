# %% [markdown]
# # Ciencia de Datos con JupyterLite

# %% [markdown]
# Este cuaderno presenta un repaso de conceptos fundamentales de ciencia de datos,
# utilizando celdas Markdown y de código en JupyterLite. A través de ejemplos simples,
# se ilustran herramientas, bibliotecas y operaciones comunes en este campo.

# %% [markdown]
# Los principales lenguajes utilizados en Ciencia de Datos son:
#
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# Algunas bibliotecas populares en Ciencia de Datos incluyen:
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# | Herramienta       | Descripción                              |
# |-------------------|------------------------------------------|
# | Jupyter Notebook  | Entorno interactivo para código en Python |
# | RStudio           | IDE para programación en R                |
# | GitHub            | Control de versiones y colaboración       |
# | VS Code           | Editor de código multiplataforma          |
# | Apache Spark      | Procesamiento de datos a gran escala      |

# %% [markdown]
# Ejemplos comunes de operaciones matemáticas:
#
# - Suma: 5 + 3
# - Resta: 10 - 4
# - Multiplicación: 6 * 7
# - División: 8 / 2

# %%
x = 10
y = 5
multiplicacion = x * y
suma = x + y
print("Multiplicación:", multiplicacion)
print("Suma:", suma)

# %%
minutos = 150
horas = minutos / 60
print(minutos, "minutos equivalen a", horas, "horas")

# %%
objetivos = ["Aprender Python", "Conocer herramientas de ciencia de datos", "Practicar en JupyterLite"]
print("Objetivos del curso:")
for objetivo in objetivos:
    print("-", objetivo)

# %% [markdown]
# **Autor:** Claudio Nicolás Muñoz Cantillana

# %% [markdown]
# Para compartir el cuaderno en GitHub o GitLab:
# 1. Guardar el archivo `.ipynb` desde JupyterLite.
# 2. Subirlo a un repositorio público en GitHub o GitLab.
# 3. Copiar y compartir el enlace del repositorio.

# %% [markdown]
# Recuerda tomar una captura de pantalla de la primera página del cuaderno una vez completado
# y subirla en formato .png o .jpg para la revisión por pares.
